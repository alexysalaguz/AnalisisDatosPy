# %%
pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 19.2 MB/s  0:00:00eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 35.3 MB/s  0:00:00m0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
#importamos libreria
import pandas as pd
# Out:
# ''

# %%
data = [['Juan',25],['Pedro',23],['Luis',45]]
df = pd.DataFrame(data)
df.head()
# Out:
#        0   1
# 0   Juan  25
# 1  Pedro  23
# 2   Luis  45

# %%
df = pd.read_csv('/workspaces/AnalisisDatosPy/sesion1/utils/utils/data/data.csv')
df.head()
# Out:
#   nombre  edad     ciudad
# 0   Juan    25     Madrid
# 1  María    30  Barcelona
# 2  Pedro    35    Sevilla

# %%
df = pd.read_csv('/workspaces/AnalisisDatosPy/sesion1/utils/utils/data/data_without_header',
                 sep=',',
                 header=None
                 )
df.head()
# Out:
#        0   1          2
# 0   Juan  25     Madrid
# 1  María  30  Barcelona
# 2  Pedro  35    Sevilla

# %%
df = pd.read_json('/workspaces/AnalisisDatosPy/sesion1/utils/utils/data/data.json')
df.head()
# Out:
#   nombre  edad     ciudad
# 0   Juan    25     Madrid
# 1  María    30  Barcelona
# 2  Pedro    35    Sevilla
